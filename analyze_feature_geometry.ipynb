# %%
from interpreting_neurons_utils import *
# Out:
# /hpi/fs00/home/jim.maar/miniconda3/envs/othello-env/lib/python3.11/site-packages/accelerate/utils/imports.py:274: UserWarning: `ACCELERATE_DISABLE_RICH` is deprecated and will be removed in v0.22.0 and deactivated by default. Please use `ACCELERATE_ENABLE_RICH` if you wish to use `rich`.
#   warnings.warn(

# %% [markdown]
# # Test Toy Models Of Superposition Hypothesis
# - They said There might be orthogonal subspaces and overcomplete groups of features in all the subspaces
# - I think visualizing this is best and might produce cool insights

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# vary layer
# add neurons

features = {}
for probe_name in ["linear"]:
    for direction_str, direction_int in probe_directions[probe_name].items():
        name = short_cuts[direction_str]
        for row in range(8):
            for col in range(8):
                label = tuple_to_label((row, col))
                name = f"{short_cuts[direction_str]}:{label}"
                feature = get_probe(0, probe_name, "mid")[0, :, row, col, direction_int]
                feature = feature / feature.norm()
                features[name] = feature

# %%
def get_feature_graph(features : Dict[str, Float[Tensor, 'd_model']], threshold = 0.2):
    G = nx.Graph()
    for feature_name, feature in features.items():
        G.add_node(feature_name)
    for feature_name, feature in features.items():
        for other_feature_name, other_feature in features.items():
            if feature_name == other_feature_name:
                continue
            # print(feature.shape, other_feature.shape)
            if (feature @ other_feature).item() > threshold:
                G.add_edge(feature_name, other_feature_name)
    return G

# %%
G = get_feature_graph(features)

# %%
plt.figure(figsize=(20, 15))
nx.draw(G, with_labels=True, pos=nx.spring_layout(G, k=0.5))
# set width and height to 1000 and do plt show
plt.show()

# %%
"""
Function that returns the connected groups in the graph, connected means that every member in the group has an edge to at leas k other members in the group
"""
def get_connected_groups(G, k = 2):
    connected_groups = []
    for node in G.nodes():
        group = set([node])
        for _ in range(k):
            new_group = set()
            for member in group:
                new_group.update(set(G.neighbors(member)))
            group.update(new_group)
        connected_groups.append(group)
    return connected_groups

connected_groups = get_connected_groups(G, k=2)
long_groups = [group for group in connected_groups if len(group) > 1]
for group in long_groups:
    print(group)
# print([group for group in connected_groups if len(group) > 1])
# Out:
# {'M:E3', 'E:A7', 'E:H0', 'Y:C2', 'Y:E3', 'M:E4', 'M:D3', 'M:D4', 'Y:D3', 'Y:E4', 'Y:F4', 'Y:D4'}
# {'Y:A6', 'E:E3', 'Y:G1', 'M:A2', 'Y:B7', 'M:C7', 'M:G0', 'M:A6', 'M:A1', 'M:C0', 'M:F0', 'M:G1', 'E:D4', 'M:H0', 'Y:G0', 'E:D3', 'M:B7', 'M:A7', 'M:A0', 'Y:H0', 'M:H1', 'Y:A1', 'Y:A7', 'M:B6', 'Y:H1', 'E:E4'}
# {'Y:A6', 'E:E3', 'Y:G1', 'M:A2', 'Y:B7', 'M:C7', 'M:G0', 'M:A6', 'M:A1', 'M:C0', 'M:F0', 'M:G1', 'E:D4', 'M:H0', 'Y:G0', 'E:D3', 'M:B7', 'M:A7', 'M:A0', 'Y:H0', 'M:H1', 'Y:A1', 'Y:A7', 'M:B6', 'Y:H1', 'E:E4'}
# {'Y:A6', 'E:E3', 'Y:G1', 'M:A2', 'Y:B7', 'M:C7', 'M:E0', 'M:G0', 'M:A6', 'M:A1', 'M:C0', 'M:F0', 'M:C6', 'E:D4', 'M:G1', 'M:H0', 'Y:G0', 'E:D3', 'M:B7', 'M:A7', 'M:A0', 'Y:H0', 'Y:C0', 'M:D7', 'M:H1', 'Y:A1', 'Y:A7', 'M:B6', 'M:B0', 'Y:H1', 'E:E4'}
# {'Y:A6', 'E:E3', 'Y:G1', 'M:A2', 'Y:B7', 'M:C7', 'M:G0', 'M:A6', 'M:A1', 'M:C0', 'M:F0', 'M:C6', 'E:D4', 'M:G1', 'M:H0', 'Y:G0', 'E:D3', 'M:B7', 'M:A7', 'M:A0', 'Y:H0', 'M:D7', 'M:H1', 'Y:A1', 'Y:A7', 'M:B6', 'Y:H1', 'E:E4'}
# {'Y:D3', 'E:G1', 'M:D3', 'E:H0', 'Y:D4'}
# {'E:G6', 'E:H7'}
# {'M:E3', 'E:A7', 'E:H0', 'Y:E3', 'M:E4', 'M:D3', 'M:D4', 'Y:D3', 'E:G1', 'Y:E4', 'Y:D4'}
# {'E:G6', 'E:H7'}
# {'Y:B1', 'Y:B0', 'M:A1', 'M:B0', 'Y:C0', 'Y:A2', 'M:B1', 'Y:A0', 'Y:A1'}
# {'E:D3', 'Y:B1', 'M:A0', 'E:E3', 'M:A2', 'Y:A3', 'Y:A0', 'Y:A1', 'Y:B0', 'M:A1', 'Y:A2', 'E:E4', 'E:D4'}
# {'M:A3', 'Y:A4', 'M:A0', 'M:A1', 'Y:A2', 'M:A2', 'Y:A3', 'Y:A0', 'Y:A1'}
# {'M:A3', 'Y:A4', 'Y:A5', 'M:A4', 'Y:A2', 'M:A2', 'Y:A3', 'Y:A1'}
# {'M:A5', 'M:A3', 'Y:A5', 'Y:A4', 'M:A4', 'Y:A6', 'Y:A2', 'Y:A3'}
# {'Y:A7', 'M:A5', 'M:A6', 'Y:A4', 'Y:A5', 'Y:A6', 'M:A4', 'Y:A3'}
# {'E:D3', 'M:B7', 'M:A7', 'Y:A5', 'Y:A4', 'Y:A6', 'E:E3', 'Y:B7', 'Y:A7', 'M:A5', 'M:B6', 'M:A6', 'E:E4', 'E:D4'}
# {'M:H0', 'E:D3', 'M:B7', 'M:A7', 'Y:A5', 'Y:C7', 'Y:A6', 'E:E3', 'Y:H0', 'Y:B7', 'Y:A7', 'M:A6', 'M:A1', 'M:C0', 'E:E4', 'E:D4'}
# {'M:D0', 'Y:D0', 'Y:B1', 'Y:B0', 'M:A0', 'M:B0', 'Y:C0', 'M:C0', 'Y:A0', 'Y:A1'}
# {'Y:B1', 'Y:B0', 'M:A0', 'M:B1', 'Y:A0', 'Y:A1'}
# {'M:B2', 'Y:B2'}
# {'M:B3', 'Y:B3'}
# {'M:B4', 'Y:B4'}
# {'Y:B5', 'M:B5'}
# {'Y:B6', 'M:B6', 'M:B7', 'M:A6', 'M:A7'}
# {'E:D3', 'M:B7', 'M:A7', 'Y:C7', 'Y:A6', 'E:E3', 'Y:B7', 'M:D7', 'Y:A7', 'M:C7', 'Y:D7', 'M:B6', 'M:A6', 'E:E4', 'M:C6', 'E:D4'}
# {'M:D0', 'M:E0', 'Y:B0', 'M:A0', 'M:B0', 'Y:C0', 'E:E3', 'M:C0', 'Y:A0', 'Y:D0'}
# {'M:C1', 'Y:C1'}
# {'M:D3', 'M:D4', 'E:A7', 'Y:C2', 'Y:D3', 'Y:E3', 'Y:E4', 'Y:D4', 'M:C2', 'M:E3'}
# {'M:C3', 'Y:C3'}
# {'Y:C4', 'M:C4'}
# {'M:C5', 'Y:C5'}
# {'Y:C6', 'M:C6', 'M:B7'}
# {'Y:A7', 'M:C7', 'Y:D7', 'M:B7', 'M:A7', 'Y:C7', 'Y:B7', 'M:D7', 'M:E7'}
# {'M:D0', 'M:E0', 'Y:B0', 'M:B0', 'Y:C0', 'M:C0', 'M:F0', 'Y:D0'}
# {'Y:D1', 'M:D1'}
# {'Y:D2', 'M:D2'}
# {'M:E3', 'E:A7', 'E:H0', 'Y:C2', 'Y:E3', 'M:E4', 'M:D3', 'M:D4', 'Y:D3', 'E:G1', 'Y:E4', 'Y:F4', 'Y:D4'}
# {'E:A7', 'E:H0', 'Y:C2', 'Y:E3', 'M:E4', 'Y:D4', 'M:D3', 'M:D4', 'Y:D3', 'E:G1', 'Y:E4', 'Y:F4', 'M:E3'}
# {'Y:D5', 'M:D5'}
# {'M:D6', 'Y:D6'}
# {'M:C7', 'Y:D7', 'M:B7', 'Y:C7', 'M:D7', 'Y:B7', 'M:E7'}
# {'M:D0', 'M:E0', 'Y:F0', 'M:G0', 'Y:G0', 'M:C0', 'M:F0', 'Y:E0'}
# {'M:E1', 'Y:E1'}
# {'Y:E2', 'M:E2'}
# {'M:E3', 'E:A7', 'E:H0', 'Y:C2', 'Y:E3', 'M:E4', 'M:D3', 'M:D4', 'M:F4', 'Y:D3', 'Y:E4', 'Y:F4', 'Y:D4'}
# {'M:E3', 'E:A7', 'E:H0', 'Y:C2', 'Y:E3', 'M:E4', 'M:C2', 'M:D3', 'M:D4', 'Y:D3', 'Y:E4', 'Y:F4', 'Y:D4'}
# {'M:E5', 'Y:E5'}
# {'Y:E6', 'M:E7', 'M:E6'}
# {'Y:F7', 'Y:G7', 'M:C7', 'M:E6', 'Y:E7', 'M:G7', 'M:D7', 'M:E7', 'M:F7'}
# {'Y:G0', 'M:H0', 'Y:F0', 'M:D0', 'M:E0', 'M:G0', 'Y:H0', 'M:F0', 'Y:E0'}
# {'M:G0', 'Y:F1', 'M:F1'}
# {'Y:F2', 'M:F2'}
# {'Y:F3', 'M:F3'}
# {'M:D3', 'M:D4', 'E:A7', 'M:F4', 'Y:D3', 'Y:E3', 'Y:E4', 'M:E4', 'Y:F4', 'Y:D4'}
# {'M:F5', 'Y:F5'}
# {'M:F6', 'M:F7', 'Y:F6'}
# {'Y:G7', 'Y:F7', 'Y:E7', 'M:G7', 'Y:H7', 'M:F6', 'M:E7', 'M:F7'}
# {'Y:G0', 'M:H0', 'Y:F0', 'E:D3', 'M:F1', 'Y:H0', 'E:E3', 'Y:G1', 'Y:E0', 'M:E0', 'M:G0', 'Y:H1', 'M:F0', 'E:E4', 'E:D4'}
# {'M:H0', 'Y:G0', 'E:D3', 'Y:H0', 'Y:G1', 'Y:H1', 'E:E3', 'E:E4', 'M:G1', 'E:D4', 'M:H1'}
# {'M:H2', 'M:G2', 'Y:G2', 'M:H1'}
# {'Y:G3', 'M:G3'}
# {'Y:G4', 'M:H4', 'M:G4'}
# {'M:G5', 'Y:G5', 'M:H6'}
# {'Y:G7', 'M:G6', 'M:H7', 'Y:H5', 'M:G7', 'Y:H7', 'Y:G6', 'Y:H6'}
# {'M:G6', 'Y:H5', 'Y:E7', 'M:G7', 'Y:G6', 'Y:H6', 'Y:G7', 'Y:F7', 'M:H7', 'Y:H7', 'M:E7', 'M:F7'}
# {'Y:G0', 'M:H0', 'Y:F0', 'E:D3', 'M:B7', 'M:A7', 'Y:H0', 'E:E3', 'Y:G1', 'Y:A7', 'Y:H2', 'M:G0', 'M:A1', 'Y:H1', 'M:C0', 'E:E4', 'M:G1', 'E:D4'}
# {'M:H2', 'Y:G0', 'Y:H2', 'E:D3', 'Y:H1', 'Y:H0', 'E:E3', 'Y:G1', 'E:E4', 'E:D4', 'Y:H3'}
# {'M:H2', 'Y:H2', 'M:H3', 'M:G2', 'Y:H1', 'Y:H0', 'M:H1', 'Y:H3'}
# {'M:H2', 'Y:H2', 'M:H4', 'M:H3', 'Y:H1', 'Y:H3'}
# {'M:H4', 'Y:H5', 'M:H3', 'M:G4', 'M:H5', 'Y:H7', 'Y:H4', 'Y:H6'}
# {'Y:G7', 'M:H4', 'Y:H5', 'M:H5', 'Y:H7', 'Y:G6', 'M:H6', 'Y:H4', 'Y:H6'}
# {'Y:G7', 'M:H7', 'Y:H5', 'Y:H7', 'M:G5', 'M:H5', 'Y:G6', 'M:H6', 'Y:H4', 'Y:H6'}
# {'M:G6', 'Y:H5', 'M:G7', 'Y:G6', 'M:H6', 'Y:H6', 'Y:G7', 'Y:F7', 'Y:H7', 'M:H5', 'Y:H4'}
# {'M:D0', 'E:D3', 'Y:B1', 'M:A0', 'Y:C0', 'E:E3', 'M:A2', 'Y:A1', 'M:E0', 'Y:B0', 'M:A1', 'M:B0', 'Y:A2', 'M:C0', 'M:B1', 'E:E4', 'E:D4'}
# {'M:H0', 'E:D3', 'M:B7', 'M:A7', 'M:A0', 'Y:H0', 'E:E3', 'M:A2', 'Y:A0', 'Y:A1', 'Y:A7', 'M:A1', 'M:B0', 'Y:A2', 'M:C0', 'M:B1', 'E:E4', 'E:D4'}
# {'E:D3', 'M:A0', 'E:E3', 'M:A2', 'Y:A3', 'Y:A1', 'M:A1', 'M:B0', 'Y:A2', 'M:C0', 'M:B1', 'E:E4', 'E:D4'}
# {'M:A5', 'M:A3', 'Y:A4', 'M:A4', 'Y:A2', 'Y:A3'}
# {'M:A5', 'M:A3', 'M:A6', 'Y:A4', 'Y:A5', 'M:A4', 'Y:A3'}
# {'M:A5', 'M:A3', 'M:B6', 'M:A6', 'M:B7', 'Y:A5', 'Y:A4', 'M:A7', 'M:A4', 'Y:A6'}
# {'E:D3', 'M:B7', 'M:A7', 'Y:A5', 'Y:A6', 'E:E3', 'Y:B7', 'M:D7', 'Y:A7', 'M:C7', 'M:A5', 'M:B6', 'M:A6', 'M:A4', 'Y:B6', 'E:E4', 'M:C6', 'E:D4'}
# {'M:H0', 'E:D3', 'M:B7', 'M:A7', 'Y:C7', 'Y:H0', 'E:E3', 'Y:A6', 'M:D7', 'Y:B7', 'Y:A7', 'M:C7', 'M:A5', 'M:B6', 'M:A6', 'M:A1', 'M:C0', 'Y:B6', 'E:E4', 'M:C6', 'E:D4', 'M:E7'}
# {'M:D0', 'M:A0', 'Y:C0', 'E:E3', 'M:A2', 'Y:A0', 'M:E0', 'Y:B0', 'M:A1', 'M:B0', 'M:C0', 'M:F0', 'M:B1', 'Y:D0'}
# {'Y:B1', 'M:A0', 'M:A1', 'M:B0', 'M:B1', 'M:C0', 'M:A2', 'Y:A0'}
# {'M:B2', 'Y:B2'}
# {'Y:B3', 'M:B3'}
# {'M:B4', 'Y:B4'}
# {'Y:B5', 'M:B5'}
# {'E:D3', 'M:B7', 'M:A7', 'Y:A6', 'E:E3', 'Y:B7', 'M:D7', 'M:C7', 'M:A5', 'M:B6', 'M:A6', 'Y:B6', 'E:E4', 'M:C6', 'E:D4'}
# {'Y:A6', 'E:E3', 'Y:B7', 'M:C7', 'M:A6', 'M:A1', 'M:C0', 'M:C6', 'E:D4', 'Y:C6', 'M:H0', 'E:D3', 'M:B7', 'M:A7', 'Y:C7', 'Y:H0', 'M:D7', 'Y:A7', 'M:A5', 'Y:D7', 'M:B6', 'Y:B6', 'E:E4', 'M:E7'}
# {'M:D0', 'M:H0', 'E:D3', 'M:B7', 'M:A7', 'M:A0', 'Y:C0', 'E:E3', 'Y:H0', 'M:A2', 'Y:E0', 'Y:A7', 'M:E0', 'M:G0', 'Y:B0', 'M:A1', 'M:B0', 'M:C0', 'M:F0', 'E:E4', 'M:B1', 'E:D4', 'Y:D0'}
# {'M:C1', 'Y:C1'}
# {'Y:E4', 'M:C2', 'Y:C2'}
# {'M:C3', 'Y:C3'}
# {'Y:C4', 'M:C4'}
# {'M:C5', 'Y:C5'}
# {'Y:C6', 'M:C7', 'M:B6', 'M:B7', 'M:A6', 'M:A7', 'E:E3', 'Y:B7', 'E:E4', 'M:C6', 'M:D7'}
# {'E:D3', 'M:B7', 'M:A7', 'M:E6', 'Y:C7', 'E:E3', 'Y:E7', 'M:G7', 'M:D7', 'Y:B7', 'M:C7', 'Y:D7', 'M:B6', 'M:A6', 'E:E4', 'M:C6', 'E:D4', 'M:E7', 'M:F7'}
# {'M:D0', 'M:H0', 'Y:F0', 'M:A0', 'Y:C0', 'Y:E0', 'M:E0', 'M:G0', 'Y:B0', 'M:B0', 'M:C0', 'M:F0', 'Y:D0'}
# {'Y:D1', 'M:D1'}
# {'Y:D2', 'M:D2'}
# {'E:A7', 'E:H0', 'Y:C2', 'Y:E3', 'M:E4', 'Y:D4', 'M:D3', 'M:D4', 'Y:D3', 'E:G1', 'Y:E4', 'Y:F4', 'M:E3'}
# {'E:A7', 'E:H0', 'Y:C2', 'Y:E3', 'M:E4', 'Y:D4', 'M:D3', 'M:D4', 'Y:D3', 'Y:E4', 'Y:F4', 'M:E3'}
# {'Y:D5', 'M:D5'}
# {'Y:D6', 'M:D6'}
# {'M:B7', 'M:A7', 'M:E6', 'Y:C7', 'E:E3', 'Y:E7', 'M:G7', 'M:D7', 'Y:B7', 'M:C7', 'Y:D7', 'M:B6', 'M:A6', 'E:E4', 'M:C6', 'M:E7', 'M:F7'}
# {'M:D0', 'M:H0', 'Y:G0', 'Y:F0', 'M:F1', 'M:A0', 'Y:C0', 'E:E3', 'Y:E0', 'M:E0', 'M:G0', 'M:B0', 'M:C0', 'M:F0', 'Y:D0'}
# {'M:E1', 'Y:E1'}
# {'Y:E2', 'M:E2'}
# {'M:E3', 'E:A7', 'E:H0', 'Y:C2', 'Y:E3', 'M:E4', 'M:D3', 'M:D4', 'Y:D3', 'Y:E4', 'Y:D4'}
# {'E:A7', 'E:H0', 'Y:E3', 'M:E4', 'Y:D4', 'M:D3', 'M:D4', 'Y:D3', 'Y:E4', 'Y:F4', 'M:E3'}
# {'M:E5', 'Y:E5'}
# {'M:C7', 'Y:E6', 'M:E6', 'Y:E7', 'M:G7', 'M:D7', 'M:E7', 'M:F7'}
# {'M:G6', 'M:B7', 'M:E6', 'M:A7', 'Y:C7', 'Y:E7', 'M:G7', 'M:D7', 'M:F6', 'Y:F7', 'Y:G7', 'M:C7', 'Y:D7', 'M:H7', 'Y:E6', 'M:E7', 'M:F7'}
# {'M:H0', 'M:D0', 'Y:F0', 'Y:G0', 'E:D3', 'M:F1', 'E:E3', 'Y:E0', 'M:H1', 'M:E0', 'M:G0', 'M:B0', 'M:C0', 'M:F0', 'E:E4', 'M:G1', 'E:D4', 'Y:D0'}
# {'M:H0', 'Y:G0', 'M:E0', 'M:G0', 'M:F1', 'M:F0', 'Y:F1'}
# {'Y:F2', 'M:F2'}
# {'Y:F3', 'M:F3'}
# {'Y:E3', 'Y:F4', 'M:F4'}
# {'M:F5', 'Y:F5'}
# {'Y:F7', 'M:F7', 'M:G7', 'M:F6', 'M:E7', 'Y:F6'}
# {'M:G6', 'M:E6', 'Y:F6', 'Y:E7', 'M:G7', 'M:D7', 'M:F6', 'Y:F7', 'Y:G7', 'M:C7', 'M:H7', 'M:E7', 'M:F7'}
# {'M:H0', 'Y:G0', 'M:D0', 'Y:F0', 'E:D3', 'M:F1', 'Y:H0', 'E:E3', 'Y:E0', 'Y:F1', 'M:H1', 'M:E0', 'M:G0', 'M:C0', 'M:F0', 'E:E4', 'M:G1', 'E:D4'}
# {'M:H2', 'M:H0', 'E:D3', 'Y:H0', 'Y:G1', 'E:E3', 'M:H1', 'M:G0', 'M:G2', 'M:F0', 'E:E4', 'M:G1', 'E:D4'}
# {'M:H2', 'M:H0', 'Y:G2', 'Y:H2', 'M:G2', 'M:G1', 'M:H1'}
# {'Y:G3', 'M:G3'}
# {'Y:G4', 'M:H4', 'M:G4', 'M:H3', 'M:H5', 'Y:H4'}
# {'M:H7', 'Y:G5', 'M:H5', 'M:G5', 'M:H6', 'Y:H6'}
# {'Y:G7', 'M:G6', 'M:H7', 'M:G7', 'Y:H7', 'Y:G6', 'M:E7', 'M:F7', 'M:H6'}
# {'M:G6', 'M:E6', 'Y:E7', 'M:G7', 'M:D7', 'M:F6', 'Y:G6', 'M:H6', 'Y:G7', 'Y:F7', 'M:C7', 'M:H7', 'Y:H7', 'M:E7', 'M:F7'}
# {'M:F1', 'E:E3', 'Y:G1', 'M:E0', 'M:G0', 'M:A1', 'M:C0', 'M:F0', 'M:G1', 'E:D4', 'M:H2', 'M:H0', 'Y:G0', 'M:D0', 'Y:F0', 'E:D3', 'M:B7', 'M:A7', 'Y:H0', 'M:H1', 'Y:A7', 'M:G2', 'E:E4'}
# {'M:H2', 'M:H0', 'E:D3', 'E:E3', 'Y:G1', 'M:H1', 'Y:H2', 'Y:G2', 'M:G0', 'M:G2', 'M:F0', 'E:E4', 'M:G1', 'E:D4'}
# {'M:H2', 'M:H0', 'Y:H2', 'Y:G2', 'M:G2', 'Y:H1', 'M:G1', 'M:H1', 'Y:H3'}
# {'Y:H2', 'M:H4', 'M:G4', 'M:H3', 'M:H5', 'Y:H4', 'Y:H3'}
# {'Y:G4', 'M:H4', 'M:G4', 'M:H3', 'Y:H5', 'M:H5', 'M:H6', 'Y:H4', 'Y:H3'}
# {'M:H7', 'M:H4', 'Y:H5', 'M:G4', 'M:H3', 'M:H5', 'M:G5', 'Y:H7', 'M:H6', 'Y:H4', 'Y:H6'}
# {'M:G6', 'Y:H5', 'M:G7', 'M:G5', 'M:H6', 'Y:H6', 'M:H7', 'Y:G5', 'M:H4', 'M:H5', 'Y:H7'}
# {'Y:G7', 'M:G6', 'M:H7', 'M:G7', 'M:H5', 'M:G5', 'M:E7', 'Y:G6', 'M:H6', 'M:F7', 'Y:H6'}
